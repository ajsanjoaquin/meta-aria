# %%
# !pip install tiktoken
# !pip install cohere
# !pip install pandas
# !pip install langchain
# !pip install openai

import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
from google.colab import drive
import os, sys
drive.flush_and_unmount()
#this isn't working with shared drives so whoever owns the drive should run the google colab
#or just manually add shortcut to your google drive
drive.mount('/content/drive/')
#
my_streaming_file_path = 'Aria Workshop/spotify/'
PersonA_streamingdata = "/content/drive/My Drive/" + my_streaming_file_path + "PersonA_streaming.csv"
PersonB_streamingdata = "/content/drive/My Drive/" + my_streaming_file_path + "PersonB_streaming.csv"
# Out:
# Mounted at /content/drive/

# %%
#if drive path is being weird, just upload to see langchain summarization!
#from google.colab import files
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-cfcef2f0-5b78-4500-b141-a76c19908cfb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfcef2f0-5b78-4500-b141-a76c19908cfb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains.summarize import load_summarize_chain
from langchain.docstore.document import Document
from langchain.document_loaders.csv_loader import CSVLoader
from langchain import PromptTemplate

prompt_template = """ Summarize CSV file about user's music taste. Keep summary under 5 to 10 sentences.
Timeline:

{text}


TL'DR: """

os.environ["OPENAI_API_KEY"] = ""
PROMPT = PromptTemplate(template=prompt_template, input_variables=["text"])
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")
chain = load_summarize_chain(llm, chain_type="stuff", prompt=PROMPT)

loader = CSVLoader('PersonA_streaming.csv')

docs = loader.load()

chain.run(docs)
# Out:
# "The user's music taste includes a variety of artists and genres. They have listened to tracks from artists such as Anetha, Sugar, Niki Istrefi, Nebuchadnezzar, peachlyfe, Amotik, Ben Klock, Fadi Mohem, JakoJako, Josey Rebelle, DJ Marcelle, Kerrie, Zack Fox, Legowelt, Mareena, Vel, Kai Campos, and Speedy J. The tracks range from techno and house to experimental and hip-hop. The user has also listened to remixes and has a preference for underground and electronic music."

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains.summarize import load_summarize_chain
from langchain.docstore.document import Document
from langchain.document_loaders.csv_loader import CSVLoader
from langchain import PromptTemplate

prompt_template = """ Summarize CSV file about user's music taste. Keep summary under 5 to 10 sentences.
Timeline:

{text}


TL'DR: """

os.environ["OPENAI_API_KEY"] = "sk-"
PROMPT = PromptTemplate(template=prompt_template, input_variables=["text"])
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")
chain = load_summarize_chain(llm, chain_type="stuff", prompt=PROMPT)

loader = CSVLoader('PersonB_streaming.csv')

docs = loader.load()

chain.run(docs)
# Out:
# 'The user\'s music taste includes a mix of rock, metal, and alternative genres. They have listened to artists such as Hinder, Metallica, System Of A Down, The Offspring, Zomboy, Slipknot, Skillet, Disturbed, and Marilyn Manson. Some of their top tracks include "Wherever I May Roam" by Metallica, "Genocidal Humanoidz" by System Of A Down, "Psychosocial" by Slipknot, and "This Is The New Shit" by Marilyn Manson. They also have a preference for heavier and more intense songs, with tracks like "All American Nightmare" by Hinder and "Inside the Fire" by Disturbed.'
